# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/bawang_merah
# Out:
# /content/drive/MyDrive/bawang_merah

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.19 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="70aXkkUVBoaaS0bxymsy")
project = rf.workspace("deteksi-bawang").project("deteksi-bawang")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.3.8, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to deteksi-bawang-1 in yolov8:: 100%|██████████| 1232/1232 [00:07<00:00, 175.42it/s]

# %%
# !yolo train model=yolov8m.pt data=/content/drive/MyDrive/bawang_merah/deteksi-bawang-1/data.yaml epochs=150 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 95.6MB/s]
# Ultralytics 8.3.19 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo predict model=/content/drive/MyDrive/bawang_merah/runs/detect/train3/weights/best.pt conf=0.2 source=/content/busuk.jpg
# Out:
# Ultralytics 8.3.19 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/busuk.jpg: 384x640 1 BAWANG-TIDAK-LAYAK, 65.4ms
# Speed: 2.4ms preprocess, 65.4ms inference, 724.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo mode=export model=/content/drive/MyDrive/bawang_merah/runs/detect/train3/weights/best.pt format=onnx imgsz=640
# Out:
# Ultralytics 8.3.19 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/bawang_merah/runs/detect/train3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (49.6 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 289.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 334.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 236.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 252.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 263.8 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.3s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim', 'onnxruntime']
# ...

# %%
# !pip install tf2onnx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.8/455.8 kB 6.9 MB/s eta 0:00:00
# ...

# %%
# !yolo mode=export model=/content/drive/MyDrive/bawang_merah/runs/detect/train2/weights/best.pt format=onnx imgsz=640
# Out:
# /bin/bash: line 1: yolo: command not found
